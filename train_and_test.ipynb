# %%
from matplotlib import pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import xarray
import pandas as pd
from sklearn import preprocessing
from scipy import interpolate
from src.data_utils.data_processing import leap_years

# %%
f0 = xarray.open_dataset('data_mounted/cmip/pr_day_MRI-CGCM3_rcp45_r1i1p1_20060101-20151231.nc')
df0 = f0.to_dataframe()

# %%
df0

# %% [markdown]
# To Save and Load
